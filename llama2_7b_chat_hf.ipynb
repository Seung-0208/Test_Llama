# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/llama_test/Test_Llama/
# Out:
# /content/drive/MyDrive/llama_test/Test_Llama

# %%
# !git config --global user.email 'esybd02@nvaer.com'
# !git config --global user.name 'Seung-0208'

# %%
from transformers import pipeline

# %%
# !git add --all

# %%
# !git commit -m '원하는 아무 메시지'
# !git push
# Out:
# [main 1fab98d] 원하는 아무 메시지
#  1 file changed, 1 insertion(+)
#  create mode 100644 llama2_7b_chat_hf.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.13 KiB | 96.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Seung-0208/Test_Llama.git
#    36b455b..1fab98d  main -> main

# %%
# !git add llama2_7b_chat_hf.ipynb

# %%
# !git commit -m "test"
# Out:
# [main 3de1b87] test
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 876 bytes | 109.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Seung-0208/Test_Llama.git
#    1fab98d..3de1b87  main -> main
