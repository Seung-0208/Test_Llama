# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/llama_test/Test_Llama/Test_Llama
# Out:
# /content/drive/MyDrive/llama_test/Test_Llama/Test_Llama

# %%
# !git config --global user.email 'esybd02@naver.com'
# !git config --global user.name 'Seung-020'
